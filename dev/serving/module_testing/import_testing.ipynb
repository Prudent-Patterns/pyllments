# %%
from importlib.util import spec_from_file_location, module_from_spec
import inspect

# %%
spec = spec_from_file_location('mo', 'mod.py')

# %%
module = module_from_spec(spec)

# %%
spec.loader.exec_module(module)

# %%
module.my_sweet_func()
# Out:
# Wrappity Wrapped
# Hello World
# Who dis

# %%
module.super_decorator
# Out:
# <function mo.super_decorator(func)>

# %%
for name, obj in inspect.getmembers(module):
    if inspect.isfunction(obj) and hasattr(obj, 'contains_view'):
        print(name, obj)
# Out:
# my_sweet_func <function my_sweet_func at 0x7f036a41fb00>

# %%
import panel.interact

# %%
import functools

def my_decorator(func):
    """
    A simple decorator that prints the name of the function being called.
    
    Parameters
    ----------
    func : callable
        The function to be decorated.
    
    Returns
    -------
    callable
        The wrapped function with additional behavior.
    """
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print(f"Calling function: {func.__name__}")
        return func(*args, **kwargs)
    return wrapper

@my_decorator
def greet(name):
    """
    A simple function that greets a person by name.
    
    Parameters
    ----------
    name : str
        The name of the person to greet.
    
    Returns
    -------
    str
        A greeting message.
    """
    return f"Hello, {name}!"

# %%
inspect.hasattr(greet, '__wrapped__')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 inspect.hasattr(greet, '__wrapped__')
#
# AttributeError: module 'inspect' has no attribute 'hasattr'

# %%
import sys

# %%
inspect.getmembers(sys.modules[__name__])[-5:]
# Out:
# [('panel',
#   <module 'panel' from '/.venv/lib/python3.11/site-packages/panel/__init__.py'>),
#  ('quit', <IPython.core.autocall.ZMQExitAutocall at 0x7f036a5c17d0>),
#  ('spec',
#   ModuleSpec(name='mo', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f036a3e7050>, origin='/workspaces/pyllments/dev/serving/module_testing/mod.py')),
#  ('spec_from_file_location',
#   <function _frozen_importlib_external.spec_from_file_location(name, location=None, *, loader=None, submodule_search_locations=<object object at 0x7f03861680e0>)>),
#  ('sys', <module 'sys' (built-in)>)]

# %%
inspect.getmembers(globals())
# Out:
# [('__class__', dict),
#  ('__class_getitem__', <function dict.__class_getitem__>),
#  ('__contains__', <function dict.__contains__(key, /)>),
#  ('__delattr__',
#   <method-wrapper '__delattr__' of dict object at 0x7f036a5a1980>),
#  ('__delitem__',
#   <method-wrapper '__delitem__' of dict object at 0x7f036a5a1980>),
#  ('__dir__', <function dict.__dir__()>),
#  ('__doc__',
#   "dict() -> new empty dictionary\ndict(mapping) -> new dictionary initialized from a mapping object's\n    (key, value) pairs\ndict(iterable) -> new dictionary initialized as if via:\n    d = {}\n    for k, v in iterable:\n        d[k] = v\ndict(**kwargs) -> new dictionary initialized with the name=value pairs\n    in the keyword argument list.  For example:  dict(one=1, two=2)"),
#  ('__eq__', <method-wrapper '__eq__' of dict object at 0x7f036a5a1980>),
#  ('__format__', <function dict.__format__(format_spec, /)>),
#  ('__ge__', <method-wrapper '__ge__' of dict object at 0x7f036a5a1980>),
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'from importlib.util import spec_from_file_location',
#   "spec = spec_from_file_location('mo', 'mod.py')",
#   'spec',
#   'from importlib.util import spec_from_file_location, module_from_spec',
#   'module = module_from_spec(spec)',
#   'module',
#   'module.__dict__',
#   'module.super_decorator',
#   'spec.loader.exec_module(module)',
#   'module.__dict__',
#   'module.super_decorator',
#   'module.my_sweet_func',
#   'module.my_sweet_func()',
#   "spec = spec_from_file_location('mo', 'mod.py')",
#   'module = module_from_spec(spec)',
#   'spec.loader.exec_module(module)',
#   'module.my_sweet_func()',
#   "spec = spec_from_file_location('mo', 'mod.py')",
# ...
